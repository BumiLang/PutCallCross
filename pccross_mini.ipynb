# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import scipy.optimize as spo
import os
import glob

# %%
# OPEN_TIME = datetime.strptime('00:00:01', '%H:%M:%S')
# CLOSE_TIME = datetime.strptime('23:59:59', '%H:%M:%S')

OPEN_TIME = '00:00:00'
CLOSE_TIME = '24:00:00'

# %%
def get_opt_price_f(f_path):
    opt = pd.read_csv(f_path, encoding = 'CP949');
    opt = opt.rename(columns = {'일자' : 'BASE_DT', '시간' : 'TIME', '선물가격' : 'FUT'});
    
    opt['BASE_DT'] = pd.to_datetime(opt['BASE_DT'], format = '%Y-%m-%d')
    opt['TIME'] = pd.to_datetime(opt['TIME'], unit = 'd').apply(lambda x : (x + timedelta(seconds=0.5)).replace(microsecond = 0)).dt.time
        
    opt = pd.melt(opt, id_vars=['BASE_DT', 'TIME'], var_name= 'INST', value_name='PR');
    fut = opt.loc[opt['INST'] == 'FUT'][['BASE_DT', 'TIME', 'PR']];
    
    opt = opt.loc[(opt['INST'] != 'FUT') & (opt['INST'] < '900')];
    opt = opt.rename(columns = {'INST' : 'STRK'}); 
    opt = opt.astype({'STRK' : 'float'}); 
    
    opt = opt.reset_index(drop = True).sort_values(['BASE_DT', 'TIME', 'STRK']);
    fut = fut.reset_index(drop = True).sort_values(['BASE_DT', 'TIME']);
    
    return opt, fut;

# %%
def get_opt_price(base_ym, type, dir):
    dir_ym = dir + '/' + str(base_ym)
    
    ohlc = '_C'
    if type.lower() == 'o' :
        ohlc = '_O'
    elif type.lower() == 'h' :
        ohlc = '_H'
    elif type.lower() == 'l' :
        ohlc = '_L'
        
    copt = pd.DataFrame()
    popt = pd.DataFrame()
    fut = pd.DataFrame()
    
    base_dt = set([fn_i[0:8] for fn_i in os.listdir(dir_ym)])
    for base_dt_i in base_dt:
        
        #call option 가격 가져오기
        f_call_i = dir_ym + '/' + base_dt_i + '_Call' + ohlc + '.csv';
        [copt_i, fut_c_i] = get_opt_price_f(f_call_i);
        
        #put option 가격 가져오기
        f_put_i = dir_ym + '/' + base_dt_i + '_Put' + ohlc + '.csv';
        [popt_i, fut_p_i] = get_opt_price_f(f_put_i);        
            
        #선물 가격 재생성
        fut_i = pd.merge(fut_c_i, fut_p_i, how = 'outer', on = ['BASE_DT', 'TIME'], suffixes = ('_C', '_P'));
        fut_i['PR'] = fut_i['PR_C'].fillna(fut_i['PR_P']);
        fut_i.drop(columns = ['PR_C', 'PR_P'], inplace = True);
        
        copt = pd.concat([copt, copt_i])
        popt = pd.concat([popt, popt_i])
        fut = pd.concat([fut, fut_i])
    
    copt = copt.reset_index(drop = True).sort_values(['BASE_DT', 'TIME', 'STRK']);
    popt = popt.reset_index(drop = True).sort_values(['BASE_DT', 'TIME', 'STRK']);
    fut = fut.reset_index(drop = True).sort_values(['BASE_DT', 'TIME']);
    
    return copt, popt, fut;

# %%
def get_opt_atm(base_ym, d_dir, eqvl_srch_rng = 5):
    
    #시가
    [copt_o, popt_o, fut_o] = get_opt_price(base_ym = base_ym, type = 'o', dir = d_dir);
    
    #고가
    [copt_h, popt_h, fut_h] = get_opt_price(base_ym = base_ym, type = 'h', dir = d_dir);
    
    #저가
    [copt_l, popt_l, fut_l] = get_opt_price(base_ym = base_ym, type = 'l', dir = d_dir);
    
    #종가
    [copt_c, popt_c, fut_c] = get_opt_price(base_ym = base_ym, type = 'c', dir = d_dir);
   
    #선물/옵션 데이터 합치기
    fut = pd.merge(fut_c, fut_o, how = 'left', on =['BASE_DT', 'TIME'], suffixes=('', '_O'));
    fut = pd.merge(fut, fut_h, how = 'left', on =['BASE_DT', 'TIME'], suffixes=('', '_H'));
    fut = pd.merge(fut, fut_l, how = 'left', on =['BASE_DT', 'TIME'], suffixes=('', '_L'));
    
    fut = fut.rename(columns = {'PR' : 'FUT', 
                                'PR_O' : 'FUT_O', 
                                'PR_H' : 'FUT_H', 
                                'PR_L' : 'FUT_L', });
    
    copt = pd.merge(copt_c, copt_o, how = 'left', on =['BASE_DT', 'TIME', 'STRK'], suffixes=('', '_O'));
    copt = pd.merge(copt, copt_h, how = 'left', on =['BASE_DT', 'TIME', 'STRK'], suffixes=('', '_H'));
    copt = pd.merge(copt, copt_l, how = 'left', on =['BASE_DT', 'TIME', 'STRK'], suffixes=('', '_L'));
    
    popt = pd.merge(popt_c, popt_o, how = 'left', on =['BASE_DT', 'TIME', 'STRK'], suffixes=('', '_O'));
    popt = pd.merge(popt, popt_h, how = 'left', on =['BASE_DT', 'TIME', 'STRK'], suffixes=('', '_H'));
    popt = pd.merge(popt, popt_l, how = 'left', on =['BASE_DT', 'TIME', 'STRK'], suffixes=('', '_L'));
    
    copt_tmp = copt.rename(columns = {'PR' : 'C_PR', 
                                      'PR_O' : 'C_PR_O', 
                                      'PR_H' : 'C_PR_H', 
                                      'PR_L' : 'C_PR_L', });

    popt_tmp = popt.rename(columns = {'PR' : 'P_PR', 
                                      'PR_O' : 'P_PR_O', 
                                      'PR_H' : 'P_PR_H', 
                                      'PR_L' : 'P_PR_L', });

    opt = pd.merge(copt_tmp, popt_tmp, how = 'inner', on = ['BASE_DT', 'TIME', 'STRK']);
    opt = pd.merge(fut, opt, how = 'left', on = ['BASE_DT', 'TIME'])

    #옵션 우세 찾기
    opt.loc[opt['C_PR'] > opt['P_PR'], 'OPT_WIN'] = 'C';
    opt.loc[opt['C_PR'] < opt['P_PR'], 'OPT_WIN'] = 'P';

    opt = opt.sort_values(by = ['BASE_DT', 'STRK', 'TIME'], ascending=[True, True, True]);
    opt['OPT_WIN'] = opt.groupby(['BASE_DT', 'STRK'])['OPT_WIN'].ffill();
    opt['OPT_WIN_PRV'] = opt.groupby(['BASE_DT', 'STRK'])['OPT_WIN'].shift(1);

    opt_1st_idx = opt.groupby(['BASE_DT', 'STRK']).head(1).index;
    opt.loc[opt_1st_idx, 'OPT_WIN_PRV'] = np.where(opt.loc[opt_1st_idx, 'C_PR_O'] > opt.loc[opt_1st_idx, 'P_PR_O'], 'C', 
                                          np.where(opt.loc[opt_1st_idx, 'C_PR_O'] < opt.loc[opt_1st_idx, 'P_PR_O'], 'P', 'E'))

    #만기 및 만기까지 남은 날
    opt['MATURITY'] = opt['BASE_DT'].max();
    opt['D-Days'] = (pd.to_datetime(opt['MATURITY'], format = '%Y-%m-%d') - pd.to_datetime(opt['BASE_DT'], format = '%Y-%m-%d')).dt.days;
    opt['BizD-Days'] = opt['BASE_DT'].rank(ascending = [True, False], method = 'dense') - 1;

    opt = opt[['BASE_DT', 'MATURITY', 'D-Days', 'BizD-Days', 'TIME', 
               'FUT', 'FUT_O', 'FUT_H', 'FUT_L', 
               'STRK', 'C_PR', 'C_PR_O', 'C_PR_H', 'C_PR_L', 'P_PR', 'P_PR_O', 'P_PR_H', 'P_PR_L', 'OPT_WIN_PRV', 'OPT_WIN']];
    
    opt['EQVL_SUM'] = opt['C_PR'] + opt['P_PR'];

    opt['DIST'] = abs(opt['FUT'] - opt['STRK']);

    #atm 찾기
    atm_srch_rng = 5
    opt_srch = opt[((opt['FUT'] - atm_srch_rng <= opt['STRK']) & (opt['STRK'] <= opt['FUT'] + atm_srch_rng)) & \
                    ((opt['FUT'] - atm_srch_rng <= opt['STRK']) & (opt['STRK'] <= opt['FUT'] + atm_srch_rng))].copy();
    opt_srch = opt_srch.sort_values(['BASE_DT', 'TIME', 'EQVL_SUM', 'DIST', 'STRK'], ascending=[True, True, True, True, False])
    opt_srch['RNK'] = opt_srch.groupby(['BASE_DT','TIME']).cumcount() + 1;
                                
    opt_atm = opt_srch[opt_srch['RNK'] == 1].drop(columns = ['RNK', 'DIST']);

    opt_atm.insert(0, 'BASE_YM', base_ym);
    copt.insert(0, 'BASE_YM', base_ym);
    popt.insert(0, 'BASE_YM', base_ym);
    fut.insert(0, 'BASE_YM', base_ym);
    
    return opt_atm, copt, popt, fut;

# %%
def perf_pccrss(strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp, opt_atm):

    strg_end_buf_tm = 10*60 + strg_end_buf_tm    #전략 종료 시간 버퍼

    ent_dp = 0.5         # 진입 가격 변동
    clr_dp = 0.5         # 대응 가격 변동

    #atm 자료 시간 오름 차순으로 정렬
    opt_atm = opt_atm.sort_values(by = ['BASE_DT', 'TIME'], ascending=[True, True]);

    #A. 장 시작/종료 시간 추출
    mkt_tm_o = opt_atm.groupby(['BASE_DT'])[['BASE_DT', 'TIME']].head(1);
    mkt_tm_c = opt_atm.groupby(['BASE_DT'])[['BASE_DT', 'TIME']].tail(1);
    mkt_tm = pd.merge(mkt_tm_o, mkt_tm_c, how = 'inner', on = ['BASE_DT'], suffixes=['_O', '_C']);

    strtgy_opt = pd.merge(opt_atm, mkt_tm, how = 'inner', on = ['BASE_DT']);

    #Z. 전략 실행
    # atm_strk_cur
    # win_opt
    #손익
    tot_pl = 0
    fee = 0
    fee_rt = 0.003/100
    exec = pd.DataFrame(columns=['BASE_DT', 'TIME', 'POS_TYPE', 'TR', 'PL', 'FEE'])
    
    #position
    pos = 0
    pos_type = ''

    pr_ent = None # 진입가격
    react_hold_tm = datetime.min
    pr_h = -np.inf
    pr_l = np.inf

    for idx, atm_i in strtgy_opt.iterrows():
        tm_i = datetime.combine(atm_i['BASE_DT'], atm_i['TIME'])
        pr_i = atm_i['FUT']
        pr_o_i = atm_i['FUT_O']
        pr_h_i = atm_i['FUT_H']
        pr_l_i = atm_i['FUT_L']
        
        #장 시작 후, 일정 시간은 거래 skip
        mkt_o_tm = datetime.combine(atm_i['BASE_DT'], atm_i['TIME_O']) 
        if tm_i < mkt_o_tm + timedelta(seconds=strtg_begin_buf_tm):
            continue
        
        #장 종료 전, 청산
        mkt_c_tm = datetime.combine(atm_i['BASE_DT'], atm_i['TIME_C']) 
        if pos != 0 and mkt_c_tm - timedelta(seconds=strg_end_buf_tm) <= tm_i:
            
            pl_clr_i = np.sign(pos) * (pr_i - pr_ent)          
            fee_i = pr_i * fee_rt
            tot_pl = tot_pl + pl_clr_i - fee_i    
            
            exec_i = pd.DataFrame([{'BASE_DT' : tm_i.date(), 'TIME' : tm_i.time(), 'POS_TYPE' : pos_type, 'TR' : 'CLR', 'PL' : pl_clr_i, 'FEE' : fee_i}])
            if len(exec) == 0:
                exec = exec_i
            else:
                exec = pd.concat([exec, exec_i])

            
            pos = 0              
            react_hold_tm = tm_i + timedelta(seconds = react_hold_dt)            
            pr_ent = None # 진입가격
            pr_h = -np.inf
            pr_l = np.inf

            continue
        
        #장 종료 전, 일정 시간은 거래 skip 
        if mkt_c_tm - timedelta(seconds=strg_end_buf_tm) <= tm_i:
            continue
                
        pr_h = max(pr_h, pr_h_i)
        pr_l = min(pr_l, pr_l_i)
        
        opt_win_prv_i = atm_i['OPT_WIN_PRV']
        opt_win_i = atm_i['OPT_WIN']
        
        #1. 손절 가격대이면, 손절(대응시간 변경, 가격 초기화, 손익 반영)
        pr_lc_i = 0
        if (pos > 0 and pr_l <= pr_ent - lc_dp):
            pr_lc_i = min(pr_ent - lc_dp, pr_o_i)
        elif (pos < 0 and pr_ent + lc_dp <= pr_h):
            pr_lc_i = max(pr_ent + lc_dp, pr_o_i)
            
        if pr_lc_i != 0: 
            
            pl_lc_i = -1 * abs(pr_lc_i - pr_ent)          
            fee_i = pl_lc_i * fee_rt
            tot_pl = tot_pl + pl_lc_i - fee_i
            
            exec_i = pd.DataFrame([{'BASE_DT' : tm_i.date(), 'TIME' : tm_i.time(), 'POS_TYPE' : pos_type, 'TR' : 'LC', 'PL' : pl_lc_i, 'FEE' : fee_i}])
            if len(exec) == 0:
                exec = exec_i
            else:
                exec = pd.concat([exec, exec_i])

            
            pos = 0              
            react_hold_tm = tm_i + timedelta(seconds = react_hold_dt)
            pr_ent = pr_lc_i
            pr_h = pr_lc_i
            pr_l = pr_lc_i
            
            continue    
        
        #2. 대응 유보 시간 이내 경우, skip 
        if tm_i <= react_hold_tm:
            #2.1 put/call cross 변경 되었으면 대응방향 변경
            if (pos_type == 'L' and (opt_win_prv_i == 'C' and opt_win_i == 'P')):
                pos_type = 'S'
            elif (pos_type == 'S' and (opt_win_prv_i == 'P' and opt_win_i == 'C')):
                pos_type = 'L'     
                
            continue
        
        #3. 대응 유보 시간 이후인 경우,      
        pl_i = 0   
        
        # CALL에서 PUT 우세로 전환되었고, 
        if opt_win_prv_i == 'C' and opt_win_i == 'P':
            pos_type = 'S'

            #현재 SHORT 포지션이면, 
            if pos < 0:
                #아무 작업하지 않음
                continue
            
            #현재 LONG 포지션이면, 
            if pos > 0:
                #매도를 통한 손익 실현
                pl_i = (pr_i - pr_ent)
                fee_i = pr_i * fee_rt
                tot_pl = tot_pl + pl_i - fee_i

                exec_i = pd.DataFrame([{'BASE_DT' : tm_i.date(), 'TIME' : tm_i.time(), 'POS_TYPE' : pos_type, 'TR' : 'CLR', 'PL' : pl_i, 'FEE' : fee_i}])
                if len(exec) == 0:
                    exec = exec_i
                else:
                    exec = pd.concat([exec, exec_i])
                
            #SHORT 포지션 진입
            pos = -1

            fee_i = pr_i * fee_rt
            tot_pl = tot_pl - fee_i
            exec_i = pd.DataFrame([{'BASE_DT' : tm_i.date(), 'TIME' : tm_i.time(), 'POS_TYPE' : pos_type, 'TR' : 'ES', 'PL' : 0, 'FEE' : fee_i}])            
            if len(exec) == 0:
                exec = exec_i
            else:
                exec = pd.concat([exec, exec_i])

            react_hold_tm = tm_i + timedelta(seconds = react_hold_dt)
            pr_ent = pr_i
            pr_h = pr_i
            pr_l = pr_i                     
                    
            continue
        
        # PUT에서 CALL 우세로 전환되었고, 
        if opt_win_prv_i == 'P' and opt_win_i == 'C':
            pos_type = 'L'
        
            #현재 LONG 포지션이면, 
            if pos > 0:
                #아무 작업하지 않음
                continue
            
            #현재 SHORT 포지션이면, 
            if pos < 0:
                #매수를 통한 손익 실현
                pl_i = (pr_ent - pr_i)                
                fee_i = pr_i * fee_rt
                tot_pl = tot_pl + pl_i - fee_i

                exec_i = pd.DataFrame([{'BASE_DT' : tm_i.date(), 'TIME' : tm_i.time(), 'POS_TYPE' : pos_type, 'TR' : 'CLR', 'PL' : pl_i, 'FEE' : fee_i}])
                if len(exec) == 0:
                    exec = exec_i
                else:
                    exec = pd.concat([exec, exec_i])

                            
            #LONG 포지션 진입
            pos = 1
            
            fee_i = pr_i * fee_rt
            tot_pl = tot_pl - fee_i
            exec_i = pd.DataFrame([{'BASE_DT' : tm_i.date(), 'TIME' : tm_i.time(), 'POS_TYPE' : pos_type, 'TR' : 'EL', 'PL' : 0, 'FEE' : fee_i}])         

            if len(exec) == 0:
                exec = exec_i
            else:
                exec = pd.concat([exec, exec_i])
            
            react_hold_tm = tm_i + timedelta(seconds = react_hold_dt)
            pr_ent = pr_i
            pr_h = pr_i
            pr_l = pr_i 
                     
            continue       
    return [tot_pl, exec]

# strtg_begin_buf_tm = 6         # 전략 시작 시간 버퍼
# strg_end_buf_tm = 337.85   #전략 종료 시간 버퍼
# react_hold_dt = 5*60 # 대응유보시간
# ent_dp = 0.5         # 진입 가격 변동
# clr_dp = 0.5         # 대응 가격 변동
# lc_dp = 1        # 손절 가격 변동
# [pl, exec] = perf_ocrss(strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp, opt_atm)
# print(pl)
# print(exec)
# exec.to_csv("exec_%d_%d.csv" % (base_ym[0], base_ym[-1]), index=False)

# %%
def _perf_pccrss(x, opt_atm):

    strtg_begin_buf_tm = x[0]         # 전략 시작 시간 버퍼
    strg_end_buf_tm = x[1]   #전략 종료 시간 버퍼
    react_hold_dt = x[2] # 대응유보시간
    ent_dp = 0.5         # 진입 가격 변동
    clr_dp = 0.5         # 대응 가격 변동
    lc_dp = x[3]         # 손절 가격 변동

    [pl, exec] = perf_pccrss(strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp, opt_atm)
    
    return -1 * pl

def print_fun(x, opt_atm, convergence):
    x = np.round(x, 2)
    print("PL = %+.4f (strtg_begin_buf_tm = %+.2f, strg_end_buf_tm = %+.2f, react_hold_dt = %+.2f, lc_dp = %+.2f)" \
                      % (-_perf_pccrss(x, opt_atm), x[0], x[1], x[2], x[3]))

def est_pccrss(opt_atm):

    bnds = ((0, 60*60), (0, 60*60), (0, 60*60), (0, 4))
    
    x0 = [3*60, 3*60, 1*60, 0.5]
    strategy = ['best1bin', 'best1exp', 'rand1exp', 'randtobest1exp', 'currenttobest1exp', 'best2exp', 'rand2exp'
                , 'randtobest1bin', 'currenttobest1bin', 'best2bin', 'rand2bin', 'rand1bin']
               
    x_init = x0
    
    opt_best = np.inf
    custom_args = [est_opt_atm]
    i = 0
    strategy_i = strategy[i]
    print("------------------- strategy : %s -------------------" % (strategy_i))
    opt = spo.differential_evolution(func = _perf_pccrss, args = custom_args, bounds = bnds, x0 = x_init, constraints=(), strategy = strategy_i
                                 , seed = i, disp = True, callback = lambda xk, convergence: print_fun(xk, est_opt_atm, convergence), polish = False, updating = 'deferred', workers = -1, maxiter = 10000)

    # while True:
        
    #     for i in range(len(strategy)):
    #         strategy_i = strategy[i]
    #         print("------------------- strategy : %s -------------------" % (strategy_i))
    #         opt = spo.differential_evolution(func = _perf_pccrss, args = custom_args, bounds = bnds, x0 = x_init, constraints=(), strategy = strategy_i
    #                                      , seed = i, disp = True, callback = lambda xk, convergence: print_fun(xk, est_opt_atm, convergence), polish = False, updating = 'deferred', workers = -1, maxiter = 3)
        
    #         x_init = opt.x
    #     if opt.fun >= opt_best:
    #         break
    #     opt_best = opt.fun

    return opt.x

# %%
def bktest_pccrss(est_opt_atm, perf_opt_atm):
    [strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp] = est_pccrss(est_opt_atm)
    [pl, exec] = perf_pccrss(strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp, perf_opt_atm)
    return [pl, exec, strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp]

# %%
d_dir = './data(mini)'
base_ym = list(range(202001, 202013))           \
            + list(range(202101, 202113))       \
            + list(range(202201, 202213))       \
            + list(range(202301, 202313))       \
            + list(range(202401, 202409))         

base_ym.sort()
base_ym_begin = base_ym[0]
base_ym_end = base_ym[-1]

opt_atm = pd.DataFrame()
copt = pd.DataFrame()
popt = pd.DataFrame()
fut = pd.DataFrame()
idx = pd.DataFrame()

for base_ym_i in base_ym:
    print(base_ym_i)
    [opt_atm_i, copt_i, popt_i, fut_i] = get_opt_atm(base_ym_i, d_dir)
    opt_atm = pd.concat([opt_atm, opt_atm_i])
    copt = pd.concat([copt, copt_i])
    popt = pd.concat([popt, popt_i])
    fut = pd.concat([fut, fut_i])
    
opt_atm.to_csv("ATM_%d_%d.csv" % (base_ym[0], base_ym[-1]), index=False)
# Out:
# 202007
# 202008
# 202009
# 202010
# 202011
# 202012
# 202101
# 202102
# 202103
# 202104
# 202105
# 202106
# 202107
# 202108
# 202109
# 202110
# 202111
# 202112
# 202201
# 202202
# 202203
# 202204
# 202205
# 202206
# 202207
# 202208
# 202209
# 202210
# 202211
# 202212
# 202301
# 202302
# 202303
# 202304
# 202305
# 202306
# 202307
# 202308
# 202309
# 202310
# 202311
# 202312
# 202401
# 202402
# 202403
# 202404
# 202405
# 202406
# 202407
# 202408

# %%
base_ym = np.sort(np.unique(opt_atm['BASE_YM']))
perf_m = 1
n_ym = len(base_ym)
    
for est_m in [1, 3, 6, 12]:
    
    pl = pd.DataFrame()
    
    for i in range(n_ym - est_m - perf_m + 1):
        data_ym = base_ym[range(i, i + est_m + perf_m)];
        [est_ym, perf_ym] = np.split(data_ym, [est_m]);
        
        est_opt_atm = opt_atm[opt_atm['BASE_YM'].isin(est_ym)]
        perf_opt_atm = opt_atm[opt_atm['BASE_YM'].isin(perf_ym)]
        
        pl.append(bktest_pccrss(est_opt_atm, perf_opt_atm))
    
        print(pl)

    pl.to_csv("pl_%d.csv" % (est_m, index=False)
    param.to_csv("param_%d.csv" % (est_m, index=False)

# print(perf_ym_i)
# print(perf_opt_atm_i)

# %%
base_ym = np.sort(np.unique(opt_atm['BASE_YM']))
perf_m = 1
n_ym = len(base_ym)
est_m = 1
i = 0

data_ym = base_ym[range(i, i + est_m + perf_m)];
[est_ym, perf_ym] = np.split(data_ym, [est_m]);

est_opt_atm = opt_atm[opt_atm['BASE_YM'].isin(est_ym)]
perf_opt_atm = opt_atm[opt_atm['BASE_YM'].isin(perf_ym)]

[strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp] = est_pccrss(est_opt_atm)
[pl, exec] = perf_pccrss(strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp, perf_opt_atm)
aa = {'perf' : pl, 'exec' : exec, 'x' : [strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp]}
# Out:
# ------------------- strategy : best1bin -------------------
# differential_evolution step 1: f(x)= -10.735139199999725
# PL = +10.7351 (strtg_begin_buf_tm = +1401.72, strg_end_buf_tm = +980.62, react_hold_dt = +368.60, lc_dp = +2.84)
# differential_evolution step 2: f(x)= -10.735139199999725
# PL = +10.7351 (strtg_begin_buf_tm = +1401.72, strg_end_buf_tm = +980.62, react_hold_dt = +368.60, lc_dp = +2.84)
# differential_evolution step 3: f(x)= -12.799997799999634
# PL = +12.8000 (strtg_begin_buf_tm = +1398.19, strg_end_buf_tm = +131.47, react_hold_dt = +385.31, lc_dp = +3.15)
# differential_evolution step 4: f(x)= -12.799997799999634
# PL = +12.8000 (strtg_begin_buf_tm = +1398.19, strg_end_buf_tm = +131.47, react_hold_dt = +385.31, lc_dp = +3.15)
# differential_evolution step 5: f(x)= -12.799997799999634
# PL = +12.8000 (strtg_begin_buf_tm = +1398.19, strg_end_buf_tm = +131.47, react_hold_dt = +385.31, lc_dp = +3.15)
# differential_evolution step 6: f(x)= -14.277840199999659
# PL = +14.2778 (strtg_begin_buf_tm = +487.67, strg_end_buf_tm = +43.75, react_hold_dt = +359.83, lc_dp = +3.46)
# differential_evolution step 7: f(x)= -14.277840199999659
# PL = +14.2778 (strtg_begin_buf_tm = +487.67, strg_end_buf_tm = +43.75, react_hold_dt = +359.83, lc_dp = +3.46)
# differential_evolution step 8: f(x)= -14.392944999999694
# PL = +14.3929 (strtg_begin_buf_tm = +717.20, strg_end_buf_tm = +43.75, react_hold_dt = +359.83, lc_dp = +3.31)
# differential_evolution step 9: f(x)= -14.392944999999694
# PL = +14.3929 (strtg_begin_buf_tm = +717.20, strg_end_buf_tm = +43.75, react_hold_dt = +359.83, lc_dp = +3.31)
# differential_evolution step 10: f(x)= -14.506050399999811
# PL = +14.5061 (strtg_begin_buf_tm = +511.62, strg_end_buf_tm = +99.55, react_hold_dt = +429.79, lc_dp = +3.94)
# differential_evolution step 11: f(x)= -14.506050399999811
# PL = +14.5061 (strtg_begin_buf_tm = +511.62, strg_end_buf_tm = +99.55, react_hold_dt = +429.79, lc_dp = +3.94)
# differential_evolution step 12: f(x)= -14.76373959999988
# PL = +14.7637 (strtg_begin_buf_tm = +635.50, strg_end_buf_tm = +46.84, react_hold_dt = +439.11, lc_dp = +3.49)
# differential_evolution step 13: f(x)= -14.76373959999988
# PL = +14.7637 (strtg_begin_buf_tm = +635.50, strg_end_buf_tm = +46.84, react_hold_dt = +439.11, lc_dp = +3.49)
# differential_evolution step 14: f(x)= -14.76373959999988
# PL = +14.7637 (strtg_begin_buf_tm = +635.50, strg_end_buf_tm = +46.84, react_hold_dt = +439.11, lc_dp = +3.49)
# differential_evolution step 15: f(x)= -14.85074799999982
# PL = +14.8507 (strtg_begin_buf_tm = +683.89, strg_end_buf_tm = +89.41, react_hold_dt = +438.44, lc_dp = +3.77)
# differential_evolution step 16: f(x)= -14.85074799999982
# PL = +14.8507 (strtg_begin_buf_tm = +683.89, strg_end_buf_tm = +89.41, react_hold_dt = +438.44, lc_dp = +3.77)
# differential_evolution step 17: f(x)= -14.85074799999982
# PL = +14.8507 (strtg_begin_buf_tm = +683.89, strg_end_buf_tm = +89.41, react_hold_dt = +438.44, lc_dp = +3.77)
# differential_evolution step 18: f(x)= -15.568839999999726
# PL = +15.5688 (strtg_begin_buf_tm = +51.46, strg_end_buf_tm = +91.52, react_hold_dt = +426.88, lc_dp = +3.48)
# differential_evolution step 19: f(x)= -15.568839999999726
# PL = +15.5688 (strtg_begin_buf_tm = +51.46, strg_end_buf_tm = +91.52, react_hold_dt = +432.90, lc_dp = +3.48)
# differential_evolution step 20: f(x)= -15.568839999999726
# PL = +15.5688 (strtg_begin_buf_tm = +51.46, strg_end_buf_tm = +91.52, react_hold_dt = +432.90, lc_dp = +3.48)
# differential_evolution step 21: f(x)= -15.568839999999726
# PL = +15.5688 (strtg_begin_buf_tm = +51.46, strg_end_buf_tm = +91.52, react_hold_dt = +432.90, lc_dp = +3.48)
# differential_evolution step 22: f(x)= -15.568839999999726
# PL = +15.5688 (strtg_begin_buf_tm = +51.46, strg_end_buf_tm = +91.52, react_hold_dt = +432.90, lc_dp = +3.48)
# differential_evolution step 23: f(x)= -15.648829199999653
# PL = +15.6488 (strtg_begin_buf_tm = +55.59, strg_end_buf_tm = +22.24, react_hold_dt = +421.49, lc_dp = +3.63)
# differential_evolution step 24: f(x)= -15.648829199999653
# PL = +15.6488 (strtg_begin_buf_tm = +55.59, strg_end_buf_tm = +22.24, react_hold_dt = +421.49, lc_dp = +3.63)
# differential_evolution step 25: f(x)= -15.668829799999692
# PL = +15.6688 (strtg_begin_buf_tm = +52.64, strg_end_buf_tm = +56.85, react_hold_dt = +430.10, lc_dp = +3.28)
# differential_evolution step 26: f(x)= -15.708834599999712
# PL = +15.7088 (strtg_begin_buf_tm = +48.54, strg_end_buf_tm = +47.05, react_hold_dt = +440.20, lc_dp = +2.99)
# differential_evolution step 27: f(x)= -15.731127399999734
# PL = +15.7311 (strtg_begin_buf_tm = +25.43, strg_end_buf_tm = +34.14, react_hold_dt = +432.20, lc_dp = +2.87)
# differential_evolution step 28: f(x)= -15.731140599999677
# PL = +15.7311 (strtg_begin_buf_tm = +27.37, strg_end_buf_tm = +96.26, react_hold_dt = +441.38, lc_dp = +3.08)
# differential_evolution step 29: f(x)= -15.768819599999771
# PL = +15.7688 (strtg_begin_buf_tm = +48.93, strg_end_buf_tm = +7.16, react_hold_dt = +438.96, lc_dp = +3.57)
# differential_evolution step 30: f(x)= -15.931120199999722
# PL = +15.9311 (strtg_begin_buf_tm = +27.37, strg_end_buf_tm = +6.25, react_hold_dt = +445.76, lc_dp = +3.74)
# differential_evolution step 31: f(x)= -15.931120199999722
# PL = +15.9311 (strtg_begin_buf_tm = +27.37, strg_end_buf_tm = +6.25, react_hold_dt = +445.76, lc_dp = +3.74)
# differential_evolution step 32: f(x)= -15.931120199999722
# PL = +15.9311 (strtg_begin_buf_tm = +27.37, strg_end_buf_tm = +6.25, react_hold_dt = +445.76, lc_dp = +3.74)
# differential_evolution step 33: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +445.32, lc_dp = +3.49)
# differential_evolution step 34: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +445.32, lc_dp = +3.49)
# differential_evolution step 35: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +445.32, lc_dp = +3.49)
# differential_evolution step 36: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +445.32, lc_dp = +3.49)
# differential_evolution step 37: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +441.45, lc_dp = +3.56)
# differential_evolution step 38: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +441.45, lc_dp = +3.56)
# differential_evolution step 39: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +441.45, lc_dp = +3.56)
# differential_evolution step 40: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +441.45, lc_dp = +3.56)
# differential_evolution step 41: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +441.45, lc_dp = +3.56)
# differential_evolution step 42: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +441.45, lc_dp = +3.56)
# differential_evolution step 43: f(x)= -15.971139399999629
# PL = +15.9711 (strtg_begin_buf_tm = +23.53, strg_end_buf_tm = +67.79, react_hold_dt = +441.45, lc_dp = +3.56)

# %%
x = pd.DataFrame(columns = ('strtg_begin_buf_tm', 'strg_end_buf_tm', 'react_hold_dt', 'lc_dp'))
x.loc[0] = [strtg_begin_buf_tm, strg_end_buf_tm, react_hold_dt, lc_dp]
aa = {'perf' : pl, 'exec' : exec, 'x' : x}
print(aa)
# Out:
# {'perf': np.float64(-5.290903399999746), 'exec':        BASE_DT      TIME POS_TYPE   TR    PL       FEE
# 0   2020-01-10  09:01:20        L   EL  0.00  0.008858
# 0   2020-01-10  11:34:50        S  CLR -0.28  0.008849
# 0   2020-01-10  11:34:50        S   ES  0.00  0.008849
# 0   2020-01-10  11:48:20        L  CLR -0.08  0.008852
# 0   2020-01-10  11:48:20        L   EL  0.00  0.008852
# ..         ...       ...      ...  ...   ...       ...
# 0   2020-02-13  14:21:00        S  CLR -0.04  0.009073
# 0   2020-02-13  14:21:00        S   ES  0.00  0.009073
# 0   2020-02-13  14:58:10        L  CLR -0.04  0.009074
# 0   2020-02-13  14:58:10        L   EL  0.00  0.009074
# 0   2020-02-13  15:34:00        S  CLR -1.88  0.009018
#
# [282 rows x 6 columns], 'x':    strtg_begin_buf_tm  strg_end_buf_tm  react_hold_dt     lc_dp
# 0           23.528643        67.793161     441.450295  3.564799}
